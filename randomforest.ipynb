# %%
import pandas as pd

# %%
full_df = pd.read_csv('dataset/train.csv')
df = full_df.copy()

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

def update_train_df(dataframe):
    imputers = {
        'name_imputer': SimpleImputer(strategy='constant', fill_value='Unknown Unknown'),
        'num_imputer': SimpleImputer(strategy='median'),
        'cat_imputer': SimpleImputer(strategy='constant', fill_value='Unknown'),
    }

    num_col = ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']
    cat_cols = ['HomePlanet', 'CryoSleep', 'Cabin', 'Destination', 'VIP']
    
    df = dataframe.copy()

    # Impute Part
    df.loc[:, 'Name'] = imputers['name_imputer'].fit_transform(df.loc[:, 'Name'].to_frame())
    df.loc[:, num_col] = imputers['num_imputer'].fit_transform(df.loc[:, num_col])
    df.loc[:, cat_cols] = imputers['cat_imputer'].fit_transform(df.loc[:, cat_cols])

    # Feature engineering Part
    df.loc[:, 'FirstName'] = df.loc[:, 'Name'].apply(lambda x: x.split()[0])
    df.loc[:, 'LastName'] = df.loc[:, 'Name'].apply(lambda x: x.split()[1])

    df.loc[:, 'PassengerGGGG'] = df.loc[:, 'PassengerId'].apply(lambda x: int(x.split('_')[0]))
    df.loc[:, 'PassengerPP'] = df.loc[:, 'PassengerId'].apply(lambda x: int(x.split('_')[1]))
    
    df.loc[:, 'NumberOfFellows'] = df.groupby('PassengerGGGG')['PassengerGGGG'].transform('count')
    df.loc[:, 'IsAlone'] = df.loc[:, 'NumberOfFellows'].apply(lambda x: 1 if x == 1 else 0)

    df['cabin_deck'] = df['Cabin'].apply(lambda x: x.split('/')[0] if x != 'Unknown' else 'U')
    df['cabin_num'] = df['Cabin'].apply(lambda x: int(x.split('/')[1]) if x != 'Unknown' else -1)
    df['cabin_side'] = df['Cabin'].apply(lambda x: x.split('/')[2] if x != 'Unknown' else 'U')

    df.loc[:, 'TotalSpend'] = df.loc[:, ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']].sum(axis=1)
    df['IsSpendingZero'] = (df['TotalSpend'] == 0).astype(int)

    # Removing unnecessary columns
    df.drop(['Cabin', 'Name', 'PassengerId'], inplace=True, axis=1)
    df.drop(['FirstName', 'LastName', 'PassengerGGGG'], inplace=True, axis=1)


    # std_scalers = {}

    # num_cols = df.select_dtypes('float').columns

    # for num_col in num_cols:
    #     scaler = StandardScaler()
    #     df.loc[:, num_col] = scaler.fit_transform(df.loc[:, num_col])

    #     std_scalers = 

    # Encoding 
    cat_data = df.select_dtypes('object')
    cat_data.loc[:, ['CryoSleep', 'VIP']] = cat_data.loc[:, ['CryoSleep', 'VIP']].astype('str')
    
    one_hot_encoder = OneHotEncoder(drop='first', dtype=int)
    
    cat_data_encoded = one_hot_encoder.fit_transform(cat_data)
    encoded_feature_names = one_hot_encoder.get_feature_names_out(cat_data.columns)
    
    cat_encoded = pd.DataFrame(cat_data_encoded.toarray(), columns = encoded_feature_names, index=cat_data.index)
    
    non_cat = df.drop(cat_data.columns, axis=1)
    df = pd.concat([non_cat, cat_encoded], axis=1)
    
    df.loc[:, 'Transported'] = df.loc[:, 'Transported'].astype(int)
    
    return df, imputers, one_hot_encoder

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

def update_test_df(dataframe, imputers, one_hot_encoder):
    num_col = ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']
    cat_cols = ['HomePlanet', 'CryoSleep', 'Cabin', 'Destination', 'VIP']
    
    df = dataframe.copy()

    # Impute Part
    df.loc[:, 'Name'] = imputers['name_imputer'].transform(df.loc[:, 'Name'].to_frame())
    df.loc[:, num_col] = imputers['num_imputer'].transform(df.loc[:, num_col])
    df.loc[:, cat_cols] = imputers['cat_imputer'].transform(df.loc[:, cat_cols])

    # Feature engineering Part
    df.loc[:, 'FirstName'] = df.loc[:, 'Name'].apply(lambda x: x.split()[0])
    df.loc[:, 'LastName'] = df.loc[:, 'Name'].apply(lambda x: x.split()[1])

    df.loc[:, 'PassengerGGGG'] = df.loc[:, 'PassengerId'].apply(lambda x: int(x.split('_')[0]))
    df.loc[:, 'PassengerPP'] = df.loc[:, 'PassengerId'].apply(lambda x: int(x.split('_')[1]))
    
    df.loc[:, 'NumberOfFellows'] = df.groupby('PassengerGGGG')['PassengerGGGG'].transform('count')
    df.loc[:, 'IsAlone'] = df.loc[:, 'NumberOfFellows'].apply(lambda x: 1 if x == 1 else 0)

    df['cabin_deck'] = df['Cabin'].apply(lambda x: x.split('/')[0] if x != 'Unknown' else 'U')
    df['cabin_num'] = df['Cabin'].apply(lambda x: int(x.split('/')[1]) if x != 'Unknown' else -1)
    df['cabin_side'] = df['Cabin'].apply(lambda x: x.split('/')[2] if x != 'Unknown' else 'U')

    df.loc[:, 'TotalSpend'] = df.loc[:, ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']].sum(axis=1)
    df['IsSpendingZero'] = (df['TotalSpend'] == 0).astype(int)

    # Removing unnecessary columns
    df.drop(['Cabin', 'Name', 'PassengerId'], inplace=True, axis=1)
    df.drop(['FirstName', 'LastName', 'PassengerGGGG'], inplace=True, axis=1)

    # Encoding
    cat_data = df.select_dtypes('object')
    cat_data.loc[:, ['CryoSleep', 'VIP']] = cat_data.loc[:, ['CryoSleep', 'VIP']].astype('str')
        
    cat_data_encoded = one_hot_encoder.transform(cat_data)
    encoded_feature_names = one_hot_encoder.get_feature_names_out(cat_data.columns)
    
    cat_encoded = pd.DataFrame(cat_data_encoded.toarray(), columns = encoded_feature_names, index=cat_data.index)
    
    non_cat = df.drop(cat_data.columns, axis=1)
    df = pd.concat([non_cat, cat_encoded], axis=1)
    
    return df

# %%
df_train_updated, train_imputers, train_ohe = update_train_df(df_train)
# Out:
# /tmp/ipykernel_131962/3056761461.py:68: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1 0 0 ... 0 0 0]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'Transported'] = df.loc[:, 'Transported'].astype(int)

# %%
df_test_updated = update_test_df(df_test, train_imputers, train_ohe)

# %%
X_train = df_train_updated.drop('Transported', axis=1)
y_train = df_train_updated.loc[:, 'Transported']

X_test = df_test_updated.drop('Transported', axis=1)
y_test = df_test_updated.loc[:, 'Transported']

# %%
import optuna
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 50),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 50),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 50),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None]),
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False]),
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy', 'log_loss'])
    }

    model = RandomForestClassifier(**params, random_state=42, n_jobs=-1)
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=200)

print("Best trial:")
print(study.best_trial.params)
# Out:
# [I 2025-07-07 23:25:24,868] A new study created in memory with name: no-name-21a35828-51e8-4325-b637-757c242b3830
# [I 2025-07-07 23:25:34,443] Trial 0 finished with value: 0.7851606162948865 and parameters: {'n_estimators': 848, 'max_depth': 17, 'min_samples_split': 33, 'min_samples_leaf': 34, 'max_features': None, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 0 with value: 0.7851606162948865.
# [I 2025-07-07 23:25:37,512] Trial 1 finished with value: 0.8042858251141718 and parameters: {'n_estimators': 301, 'max_depth': 50, 'min_samples_split': 34, 'min_samples_leaf': 22, 'max_features': None, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 1 with value: 0.8042858251141718.
# [I 2025-07-07 23:25:38,703] Trial 2 finished with value: 0.7985335326275285 and parameters: {'n_estimators': 228, 'max_depth': 40, 'min_samples_split': 10, 'min_samples_leaf': 13, 'max_features': 'log2', 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1 with value: 0.8042858251141718.
# [I 2025-07-07 23:25:40,067] Trial 3 finished with value: 0.7874604988906071 and parameters: {'n_estimators': 290, 'max_depth': 42, 'min_samples_split': 44, 'min_samples_leaf': 37, 'max_features': 'sqrt', 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 1 with value: 0.8042858251141718.
# [I 2025-07-07 23:25:44,416] Trial 4 finished with value: 0.7881795095914641 and parameters: {'n_estimators': 665, 'max_depth': 35, 'min_samples_split': 26, 'min_samples_leaf': 22, 'max_features': 'sqrt', 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 1 with value: 0.8042858251141718.
# [I 2025-07-07 23
 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 22, 'max_features': 'sqrt', 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:42:59,929] Trial 180 finished with value: 0.8051487207071151 and parameters: {'n_estimators': 756, 'max_depth': 21, 'min_samples_split': 13, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:43:07,354] Trial 181 finished with value: 0.8054362836115004 and parameters: {'n_estimators': 757, 'max_depth': 21, 'min_samples_split': 13, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:43:14,937] Trial 182 finished with value: 0.8035666075335275 and parameters: {'n_estimators': 754, 'max_depth': 21, 'min_samples_split': 13, 'min_samples_leaf': 19, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:43:22,726] Trial 183 finished with value: 0.8038543773177 and parameters: {'n_estimators': 785, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 21, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:43:30,351] Trial 184 finished with value: 0.8052925021593078 and parameters: {'n_estimators': 764, 'max_depth': 21, 'min_samples_split': 14, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:43:38,056] Trial 185 finished with value: 0.8039974346906371 and parameters: {'n_estimators': 763, 'max_depth': 21, 'min_samples_split': 14, 'min_samples_leaf': 17, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:43:46,183] Trial 186 finished with value: 0.8032791480690358 and parameters: {'n_estimators': 798, 'max_depth': 18, 'min_samples_split': 12, 'min_samples_leaf': 19, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:43:54,983] Trial 187 finished with value: 0.8037104924256138 and parameters: {'n_estimators': 828, 'max_depth': 23, 'min_samples_split': 14, 'min_samples_leaf': 22, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:44:03,165] Trial 188 finished with value: 0.8050049392549224 and parameters: {'n_estimators': 779, 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:44:10,145] Trial 189 finished with value: 0.8021284826919197 and parameters: {'n_estimators': 706, 'max_depth': 19, 'min_samples_split': 11, 'min_samples_leaf': 18, 'max_features': None, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:44:17,857] Trial 190 finished with value: 0.803423032961122 and parameters: {'n_estimators': 741, 'max_depth': 21, 'min_samples_split': 12, 'min_samples_leaf': 23, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:44:25,401] Trial 191 finished with value: 0.8050049392549224 and parameters: {'n_estimators': 746, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:44:33,344] Trial 192 finished with value: 0.8035669178532086 and parameters: {'n_estimators': 767, 'max_depth': 17, 'min_samples_split': 18, 'min_samples_leaf': 21, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:44:41,021] Trial 193 finished with value: 0.8038540669980192 and parameters: {'n_estimators': 734, 'max_depth': 20, 'min_samples_split': 15, 'min_samples_leaf': 19, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:44:48,578] Trial 194 finished with value: 0.8054362836115004 and parameters: {'n_estimators': 757, 'max_depth': 19, 'min_samples_split': 13, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:44:56,252] Trial 195 finished with value: 0.8038542738778066 and parameters: {'n_estimators': 787, 'max_depth': 21, 'min_samples_split': 13, 'min_samples_leaf': 21, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:45:03,935] Trial 196 finished with value: 0.8042851010349162 and parameters: {'n_estimators': 760, 'max_depth': 22, 'min_samples_split': 10, 'min_samples_leaf': 18, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:45:12,173] Trial 197 finished with value: 0.8050049392549224 and parameters: {'n_estimators': 804, 'max_depth': 24, 'min_samples_split': 11, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:45:19,873] Trial 198 finished with value: 0.8038542738778064 and parameters: {'n_estimators': 773, 'max_depth': 17, 'min_samples_split': 16, 'min_samples_leaf': 22, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# [I 2025-07-07 23:45:27,198] Trial 199 finished with value: 0.8038540669980192 and parameters: {'n_estimators': 719, 'max_depth': 20, 'min_samples_split': 14, 'min_samples_leaf': 19, 'max_features': None, 'bootstrap': True, 'criterion': 'log_loss'}. Best is trial 75 with value: 0.8054362836115004.
# Best trial:
# {'n_estimators': 758, 'max_depth': 20, 'min_samples_split': 19, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'criterion': 'entropy'}

# %%
study.best_value
# Out:
# 0.8054362836115004

# %%
train, train_imputers, train_ohe = update_train_df(full_df)
# Out:
# /tmp/ipykernel_131962/3056761461.py:68: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0 1 0 ... 1 0 1]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'Transported'] = df.loc[:, 'Transported'].astype(int)

# %%
test_df = pd.read_csv('dataset/test.csv')
test = update_test_df(test_df, train_imputers, train_ohe)

# %%
X = train.drop('Transported', axis=1)
y = train.loc[:, 'Transported']

# %%
best_params = study.best_trial.params

# %%
best_model = RandomForestClassifier(**best_params)
best_model.fit(X, y)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=20, max_features=None,
#                        min_samples_leaf=20, min_samples_split=19,
#                        n_estimators=758)

# %%
y_pred = best_model.predict(test)
y_pre = y_pred.astype(bool)

# %%
test_df = pd.read_csv('dataset/test.csv')


submission = pd.DataFrame({
    'PassengerId': test_df['PassengerId'],
    'Transported' : y_pred.astype(bool)
})
submission
# Out:
#      PassengerId  Transported
# 0        0013_01         True
# 1        0018_01        False
# 2        0019_01         True
# 3        0021_01         True
# 4        0023_01         True
# ...          ...          ...
# 4272     9266_02         True
# 4273     9269_01        False
# 4274     9271_01         True
# 4275     9273_01         True
# 4276     9277_01         True
#
# [4277 rows x 2 columns]

# %%
submission.to_csv('randomforest-80.54.csv', index=False)

# %%
best_params
# Out:
# {'n_estimators': 758,
#  'max_depth': 20,
#  'min_samples_split': 19,
#  'min_samples_leaf': 20,
#  'max_features': None,
#  'bootstrap': True,
#  'criterion': 'entropy'}
