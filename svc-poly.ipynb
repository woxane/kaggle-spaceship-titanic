# %%
import pandas as pd

# %%
full_df = pd.read_csv('dataset/train.csv')
df = full_df.copy()

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

def update_train_df(dataframe):
    imputers = {
        'name_imputer': SimpleImputer(strategy='constant', fill_value='Unknown Unknown'),
        'num_imputer': SimpleImputer(strategy='median'),
        'cat_imputer': SimpleImputer(strategy='constant', fill_value='Unknown'),
    }

    num_col = ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']
    cat_cols = ['HomePlanet', 'CryoSleep', 'Cabin', 'Destination', 'VIP']
    
    df = dataframe.copy()

    # Impute Part
    df.loc[:, 'Name'] = imputers['name_imputer'].fit_transform(df.loc[:, 'Name'].to_frame())
    df.loc[:, num_col] = imputers['num_imputer'].fit_transform(df.loc[:, num_col])
    df.loc[:, cat_cols] = imputers['cat_imputer'].fit_transform(df.loc[:, cat_cols])

    # Feature engineering Part
    df.loc[:, 'FirstName'] = df.loc[:, 'Name'].apply(lambda x: x.split()[0])
    df.loc[:, 'LastName'] = df.loc[:, 'Name'].apply(lambda x: x.split()[1])

    df.loc[:, 'PassengerGGGG'] = df.loc[:, 'PassengerId'].apply(lambda x: int(x.split('_')[0]))
    df.loc[:, 'PassengerPP'] = df.loc[:, 'PassengerId'].apply(lambda x: int(x.split('_')[1]))
    
    df.loc[:, 'NumberOfFellows'] = df.groupby('PassengerGGGG')['PassengerGGGG'].transform('count')
    df.loc[:, 'IsAlone'] = df.loc[:, 'NumberOfFellows'].apply(lambda x: 1 if x == 1 else 0)

    df['cabin_deck'] = df['Cabin'].apply(lambda x: x.split('/')[0] if x != 'Unknown' else 'U')
    df['cabin_num'] = df['Cabin'].apply(lambda x: int(x.split('/')[1]) if x != 'Unknown' else -1)
    df['cabin_side'] = df['Cabin'].apply(lambda x: x.split('/')[2] if x != 'Unknown' else 'U')

    df.loc[:, 'TotalSpend'] = df.loc[:, ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']].sum(axis=1)
    df['IsSpendingZero'] = (df['TotalSpend'] == 0).astype(int)

    # Removing unnecessary columns
    df.drop(['Cabin', 'Name', 'PassengerId'], inplace=True, axis=1)
    df.drop(['FirstName', 'LastName', 'PassengerGGGG'], inplace=True, axis=1)


    # std_scalers = {}

    # num_cols = df.select_dtypes('float').columns

    # for num_col in num_cols:
    #     scaler = StandardScaler()
    #     df.loc[:, num_col] = scaler.fit_transform(df.loc[:, num_col])

    #     std_scalers = 

    # Encoding 
    cat_data = df.select_dtypes('object')
    cat_data.loc[:, ['CryoSleep', 'VIP']] = cat_data.loc[:, ['CryoSleep', 'VIP']].astype('str')
    
    one_hot_encoder = OneHotEncoder(drop='first', dtype=int)
    
    cat_data_encoded = one_hot_encoder.fit_transform(cat_data)
    encoded_feature_names = one_hot_encoder.get_feature_names_out(cat_data.columns)
    
    cat_encoded = pd.DataFrame(cat_data_encoded.toarray(), columns = encoded_feature_names, index=cat_data.index)
    
    non_cat = df.drop(cat_data.columns, axis=1)
    df = pd.concat([non_cat, cat_encoded], axis=1)
    
    df.loc[:, 'Transported'] = df.loc[:, 'Transported'].astype(int)
    
    return df, imputers, one_hot_encoder

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

def update_test_df(dataframe, imputers, one_hot_encoder):
    num_col = ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']
    cat_cols = ['HomePlanet', 'CryoSleep', 'Cabin', 'Destination', 'VIP']
    
    df = dataframe.copy()

    # Impute Part
    df.loc[:, 'Name'] = imputers['name_imputer'].transform(df.loc[:, 'Name'].to_frame())
    df.loc[:, num_col] = imputers['num_imputer'].transform(df.loc[:, num_col])
    df.loc[:, cat_cols] = imputers['cat_imputer'].transform(df.loc[:, cat_cols])

    # Feature engineering Part
    df.loc[:, 'FirstName'] = df.loc[:, 'Name'].apply(lambda x: x.split()[0])
    df.loc[:, 'LastName'] = df.loc[:, 'Name'].apply(lambda x: x.split()[1])

    df.loc[:, 'PassengerGGGG'] = df.loc[:, 'PassengerId'].apply(lambda x: int(x.split('_')[0]))
    df.loc[:, 'PassengerPP'] = df.loc[:, 'PassengerId'].apply(lambda x: int(x.split('_')[1]))
    
    df.loc[:, 'NumberOfFellows'] = df.groupby('PassengerGGGG')['PassengerGGGG'].transform('count')
    df.loc[:, 'IsAlone'] = df.loc[:, 'NumberOfFellows'].apply(lambda x: 1 if x == 1 else 0)

    df['cabin_deck'] = df['Cabin'].apply(lambda x: x.split('/')[0] if x != 'Unknown' else 'U')
    df['cabin_num'] = df['Cabin'].apply(lambda x: int(x.split('/')[1]) if x != 'Unknown' else -1)
    df['cabin_side'] = df['Cabin'].apply(lambda x: x.split('/')[2] if x != 'Unknown' else 'U')

    df.loc[:, 'TotalSpend'] = df.loc[:, ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']].sum(axis=1)
    df['IsSpendingZero'] = (df['TotalSpend'] == 0).astype(int)

    # Removing unnecessary columns
    df.drop(['Cabin', 'Name', 'PassengerId'], inplace=True, axis=1)
    df.drop(['FirstName', 'LastName', 'PassengerGGGG'], inplace=True, axis=1)

    # Encoding
    cat_data = df.select_dtypes('object')
    cat_data.loc[:, ['CryoSleep', 'VIP']] = cat_data.loc[:, ['CryoSleep', 'VIP']].astype('str')
        
    cat_data_encoded = one_hot_encoder.transform(cat_data)
    encoded_feature_names = one_hot_encoder.get_feature_names_out(cat_data.columns)
    
    cat_encoded = pd.DataFrame(cat_data_encoded.toarray(), columns = encoded_feature_names, index=cat_data.index)
    
    non_cat = df.drop(cat_data.columns, axis=1)
    df = pd.concat([non_cat, cat_encoded], axis=1)
    
    return df

# %%
df_train_updated, train_imputers, train_ohe = update_train_df(df_train)
# Out:
# /tmp/ipykernel_155917/3056761461.py:68: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1 0 1 ... 1 0 0]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'Transported'] = df.loc[:, 'Transported'].astype(int)

# %%
df_test_updated = update_test_df(df_test, train_imputers, train_ohe)

# %%
X_train = df_train_updated.drop('Transported', axis=1)
y_train = df_train_updated.loc[:, 'Transported']

X_test = df_test_updated.drop('Transported', axis=1)
y_test = df_test_updated.loc[:, 'Transported']

# %%
import optuna
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

def objective(trial):
    params = {
        'C': trial.suggest_float('C', 1e-3, 100.0, log=True),
        'kernel': trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid']),
        'degree': trial.suggest_int('degree', 2, 5) if trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid']) == 'poly' else 3,
        'gamma': trial.suggest_categorical('gamma', ['scale', 'auto']),
        'coef0': trial.suggest_float('coef0', 0.0, 1.0)
    }

    # Use pipeline to scale data (important for SVM)
    model = Pipeline([
        ('scaler', StandardScaler()),
        ('svc', SVC(**params, random_state=42))
    ])

    score = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

print("Best trial:")
print(study.best_trial.params)
# Out:
# [I 2025-07-07 23:46:25,490] A new study created in memory with name: no-name-9d6d5995-28d5-4bdd-91d5-277811c6fbb3
# [I 2025-07-07 23:46:28,475] Trial 0 finished with value: 0.6685354462655613 and parameters: {'C': 9.749823349424576, 'kernel': 'sigmoid', 'gamma': 'scale', 'coef0': 0.6120813751591718}. Best is trial 0 with value: 0.6685354462655613.
# [I 2025-07-07 23:46:30,578] Trial 1 finished with value: 0.7845863180052651 and parameters: {'C': 0.07792287520230759, 'kernel': 'linear', 'gamma': 'scale', 'coef0': 0.41655711504321113}. Best is trial 1 with value: 0.7845863180052651.
# [I 2025-07-07 23:46:35,321] Trial 2 finished with value: 0.7566858892469058 and parameters: {'C': 0.02685092402729903, 'kernel': 'sigmoid', 'gamma': 'auto', 'coef0': 0.3475878655652772}. Best is trial 1 with value: 0.7845863180052651.
# [I 2025-07-07 23:46:41,676] Trial 3 finished with value: 0.7860242359670855 and parameters: {'C': 2.6515636573450165, 'kernel': 'linear', 'gamma': 'scale', 'coef0': 0.1853880392463465}. Best is trial 3 with value: 0.7860242359670855.
# [I 2025-07-07 23:46:43,571] Trial 4 finished with value: 0.7819974243466478 and parameters: {'C': 0.030598174155555005, 'kernel': 'linear', 'gamma': 'scale', 'coef0': 0.8719599270259057}. Best is trial 3 with value: 0.7860242359670855.
# [I 2025-07-07 23:46:46,525] Trial 5 finished with value: 0.6862231508826009 and parameters: {'C': 11.417036957150403, 'kernel': 'sigmoid', 'gamma': 'auto', 'coef0': 0.21001543627449792}. Best is trial 3 with value: 0.7860242359670855.
# [I 2025-07-07 23:46:49,421] Trial 6 finished with value: 0.6745757154161646 and parameters: {'C': 63.2003820224909, 'kernel': 'sigmoid', 'gamma': 'scale', 'coef0': 0.3483428670992593}. Best is trial 3 with value: 0.7860242359670855.
# [I 2025-07-07 23:46:52,688] Trial 7 finished with value: 0.7952278005058211 and parameters: {'C': 18.567785710930053, 'kernel': 'rbf', 'gamma': 'auto', 'coef0': 0.1580904651801751}. Best is trial 7 with value: 0.7952278005058211.
# [I 2025-07-07 23:47:10,369] Trial 8 finished with value: 0.7691995303828827 and parameters: {'C': 37.53086219323473, 'kernel': 'poly', 'degree': 5, 'gamma': 'scale', 'coef0': 0.9461368778784189}. Best is trial 7 with value: 0.7952278005058211.
# [I 2025-07-07 23:48:19,903] Trial 9 finished with value: 0.7864555803236634 and parameters: {'C': 60.465479773232936, 'kernel': 'linear', 'gamma': 'auto', 'coef0': 0.27858089875847303}. Best is trial 7 with value: 0.7952278005058211.
# [I 2025-07-07 23:48:22,552] Trial 10 finished with value: 0.7894750942596032 and parameters: {'C': 0.6760907351769555, 'kernel': 'rbf', 'gamma': 'auto', 'coef0': 0.011250553601292262}. Best is trial 7 with value: 0.7952278005058211.
# [I 2025-07-07 23:48:27,145] Trial 11 finished with value: 0.5025884798990428 and parameters: {'C': 0.0011885332896418958, 'kernel': 'rbf', 'gamma': 'auto', 'coef0': 7.580771889502055e-05}. Best is trial 7 with value: 0.7952278005058211.
# [I 2025-07-07 23:48:29,737] Trial 12 finished with value: 0.789762450284201 and parameters: {'C': 0.7177806824687537, 'kernel': 'rbf', 'gamma': 'auto', 'coef0': 0.061924757733451824}. Best is trial 7 with value: 0.7952278005058211.
# [I 2025-07-07 23:48:32,407] Trial 13 finished with value: 0.7896189791516894 and parameters: {'C': 0.6743770109981578, 'kernel': 'rbf', 'gamma': 'auto', 'coef0': 0.5310519146121147}. Best is trial 7 with value: 0.7952278005058211.
# [I 2025-07-07 23:48:34,991] Trial 14 finished with value: 0.7950846396929905 and parameters: {'C': 2.4274711363835633, 'kernel': 'rbf', 'gamma': 'auto', 'coef0': 0.13695019964177674}. Best is trial 7 with value: 0.7952278005058211.
# [I 2025-07-07 23:48:37,716] Trial 15 finished with value: 0.7962353050701063 and parameters: {'C': 5.14351614038726, 'kernel': 'rbf', 'gamma': 'auto', 'coef0': 0.14016039996328056}. Best is trial 15 with value: 0.7962353050701063.
# [I 2025-07-07 23:48:40,756] Trial 16 finished with value: 0.8028497690704374 and parameters: {'C': 7.343347632061625, 'kernel': 'poly', 'degree': 2, 'gamma': 'auto', 'coef0': 0.7604473808714275}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:48:43,363] Trial 17 finished with value: 0.8009797826727834 and parameters: {'C': 3.5251746349732516, 'kernel': 'poly', 'degree': 2, 'gamma': 'auto', 'coef0': 0.6857688279261438}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:48:45,345] Trial 18 finished with value: 0.7850171451623748 and parameters: {'C': 0.17500460544621455, 'kernel': 'poly', 'degree': 2, 'gamma': 'auto', 'coef0': 0.7305277336703224}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:48:47,770] Trial 19 finished with value: 0.8008357943408034 and parameters: {'C': 2.2669415677706177, 'kernel': 'poly', 'degree': 2, 'gamma': 'auto', 'coef0': 0.7543968531359405}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:48:51,266] Trial 20 finished with value: 0.687085529276076 and parameters: {'C': 0.0010605323720693453, 'kernel': 'poly', 'degree': 2, 'gamma': 'auto', 'coef0': 0.6987555511659995}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:48:53,694] Trial 21 finished with value: 0.800835587461016 and parameters: {'C': 2.8354563570054707, 'kernel': 'poly', 'degree': 2, 'gamma': 'auto', 'coef0': 0.7868656833695947}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:48:56,162] Trial 22 finished with value: 0.7953725129170567 and parameters: {'C': 1.2110558752666045, 'kernel': 'poly', 'degree': 3, 'gamma': 'auto', 'coef0': 0.6292481146332755}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:48:59,885] Trial 23 finished with value: 0.7956596620618674 and parameters: {'C': 6.958443946915022, 'kernel': 'poly', 'degree': 3, 'gamma': 'auto', 'coef0': 0.8354790009606213}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:49:01,871] Trial 24 finished with value: 0.7896189791516894 and parameters: {'C': 0.32503886120365466, 'kernel': 'poly', 'degree': 2, 'gamma': 'auto', 'coef0': 0.9994326616799821}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:49:04,274] Trial 25 finished with value: 0.7955157771697812 and parameters: {'C': 1.791595457927202, 'kernel': 'poly', 'degree': 3, 'gamma': 'auto', 'coef0': 0.5479966207469372}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:49:10,161] Trial 26 finished with value: 0.8015554256810224 and parameters: {'C': 22.66124423547344, 'kernel': 'poly', 'degree': 2, 'gamma': 'auto', 'coef0': 0.6722324879535346}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:49:14,972] Trial 27 finished with value: 0.7798404956839704 and parameters: {'C': 26.66839760687914, 'kernel': 'poly', 'degree': 4, 'gamma': 'auto', 'coef0': 0.4565021789386935}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:49:19,741] Trial 28 finished with value: 0.7891872210355368 and parameters: {'C': 18.719795797911996, 'kernel': 'poly', 'degree': 3, 'gamma': 'auto', 'coef0': 0.6361664593256782}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:49:22,946] Trial 29 finished with value: 0.8024183212739657 and parameters: {'C': 7.010686912289676, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.6776129184264966}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:49:33,115] Trial 30 finished with value: 0.7730812158325101 and parameters: {'C': 92.58282161362841, 'kernel': 'poly', 'degree': 4, 'gamma': 'scale', 'coef0': 0.5630728928471285}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:49:36,616] Trial 31 finished with value: 0.8016990002534277 and parameters: {'C': 8.511252728419207, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.683370243597374}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:49:40,600] Trial 32 finished with value: 0.8019865631578131 and parameters: {'C': 10.645952725521758, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.8359136520336428}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:49:45,392] Trial 33 finished with value: 0.8019867700376004 and parameters: {'C': 11.749819135573984, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.870935547127581}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:49:48,127] Trial 34 finished with value: 0.6630716476423462 and parameters: {'C': 12.689571196562438, 'kernel': 'sigmoid', 'gamma': 'scale', 'coef0': 0.8666632566419048}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:49:57,363] Trial 35 finished with value: 0.7861680174192781 and parameters: {'C': 4.957213455131361, 'kernel': 'linear', 'gamma': 'scale', 'coef0': 0.8066001343350522}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:50:07,263] Trial 36 finished with value: 0.8002609788517138 and parameters: {'C': 40.21095868478946, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.9221802212016652}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:50:10,345] Trial 37 finished with value: 0.6616337296805259 and parameters: {'C': 10.78620940379325, 'kernel': 'sigmoid', 'gamma': 'scale', 'coef0': 0.9061037863505714}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:50:12,422] Trial 38 finished with value: 0.7838668935448336 and parameters: {'C': 0.07055224179357458, 'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 0.99241984585234}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:50:23,393] Trial 39 finished with value: 0.7864555803236634 and parameters: {'C': 5.92259451446332, 'kernel': 'linear', 'gamma': 'scale', 'coef0': 0.7674249468058314}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:50:25,546] Trial 40 finished with value: 0.7963781555632561 and parameters: {'C': 1.1830663678430526, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.8680376595460236}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:50:29,497] Trial 41 finished with value: 0.802274229502092 and parameters: {'C': 10.382096711345323, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.821859619812532}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:50:34,474] Trial 42 finished with value: 0.8018430920253014 and parameters: {'C': 15.109539813471262, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.816624751003397}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:50:37,620] Trial 43 finished with value: 0.7545300984230588 and parameters: {'C': 0.002633787788560507, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.9406663958465212}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:50:47,181] Trial 44 finished with value: 0.8001173008394147 and parameters: {'C': 38.05226302123916, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.845560865004986}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:50:49,661] Trial 45 finished with value: 0.6656599206616016 and parameters: {'C': 63.37137255501586, 'kernel': 'sigmoid', 'gamma': 'scale', 'coef0': 0.7256796333959089}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:50:57,549] Trial 46 finished with value: 0.7861680174192781 and parameters: {'C': 4.032992190636271, 'kernel': 'linear', 'gamma': 'scale', 'coef0': 0.8927014701023717}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:04,680] Trial 47 finished with value: 0.7890443705423872 and parameters: {'C': 29.27043517554037, 'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 0.8052399937106095}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:07,480] Trial 48 finished with value: 0.7604259654821075 and parameters: {'C': 0.007866471068144313, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.5877001146815757}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:10,729] Trial 49 finished with value: 0.8019865631578131 and parameters: {'C': 8.558056715217008, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.4941007864968009}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:13,895] Trial 50 finished with value: 0.6692550776057801 and parameters: {'C': 1.3983700927849665, 'kernel': 'sigmoid', 'gamma': 'scale', 'coef0': 0.7533489430363479}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:17,224] Trial 51 finished with value: 0.8014111270293615 and parameters: {'C': 10.411972097783245, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.4071093363916082}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:20,179] Trial 52 finished with value: 0.8022743329419857 and parameters: {'C': 6.358527425767647, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.48963022760071556}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:22,795] Trial 53 finished with value: 0.7998294276153485 and parameters: {'C': 4.371410016367427, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.3726216302014217}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:27,257] Trial 54 finished with value: 0.7768203611086687 and parameters: {'C': 19.30202238347562, 'kernel': 'poly', 'degree': 5, 'gamma': 'scale', 'coef0': 0.46350145039046103}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:30,213] Trial 55 finished with value: 0.8028496656305437 and parameters: {'C': 6.6082390676319545, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.6247312975961155}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:32,578] Trial 56 finished with value: 0.8001165767601591 and parameters: {'C': 3.0617540858794015, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.6539366508915734}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:35,209] Trial 57 finished with value: 0.7912000579263404 and parameters: {'C': 0.8880972813797567, 'kernel': 'rbf', 'gamma': 'scale', 'coef0': 0.7166036883126606}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:38,285] Trial 58 finished with value: 0.8025618958463709 and parameters: {'C': 7.423116545947767, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.5936880777513526}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:43,747] Trial 59 finished with value: 0.7860242359670855 and parameters: {'C': 2.0102848862954885, 'kernel': 'linear', 'gamma': 'scale', 'coef0': 0.2944297144003232}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:46,577] Trial 60 finished with value: 0.8025621027261582 and parameters: {'C': 6.394168511475155, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.5969430421582537}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:49,268] Trial 61 finished with value: 0.8006926335279726 and parameters: {'C': 5.247241568229557, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.598938723506001}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:51,237] Trial 62 finished with value: 0.7897629674836695 and parameters: {'C': 0.41364818191685926, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.5145335830649717}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:54,203] Trial 63 finished with value: 0.8021305514897931 and parameters: {'C': 7.10778608674848, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.5875516345076202}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:51:58,682] Trial 64 finished with value: 0.802274539821773 and parameters: {'C': 15.969660678945163, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.6206986671530237}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:01,041] Trial 65 finished with value: 0.7999730021877538 and parameters: {'C': 2.8403208680499734, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.6254032374181109}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:04,414] Trial 66 finished with value: 0.7929265731914829 and parameters: {'C': 25.532007963507834, 'kernel': 'rbf', 'gamma': 'scale', 'coef0': 0.5612734918913388}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:11,360] Trial 67 finished with value: 0.7847297891377768 and parameters: {'C': 48.768240767551866, 'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 0.4931815117443155}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:16,280] Trial 68 finished with value: 0.8018430920253014 and parameters: {'C': 16.287145698454417, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.6532559639537153}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:18,529] Trial 69 finished with value: 0.7979599584171628 and parameters: {'C': 1.7611804495946204, 'kernel': 'poly', 'degree': 2, 'gamma': 'auto', 'coef0': 0.5380303720233113}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:20,531] Trial 70 finished with value: 0.7827158144081428 and parameters: {'C': 0.16455569866688302, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.457957556660541}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:23,672] Trial 71 finished with value: 0.8025619992862648 and parameters: {'C': 7.382332778122607, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.6971380907934274}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:26,251] Trial 72 finished with value: 0.8009802998722517 and parameters: {'C': 3.701028515520111, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.6883791972609306}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:29,345] Trial 73 finished with value: 0.8021306549296867 and parameters: {'C': 7.059374085617704, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.5996148947185012}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:33,774] Trial 74 finished with value: 0.7901946221599283 and parameters: {'C': 15.059580109056466, 'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 0.6427352222355196}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:36,736] Trial 75 finished with value: 0.8015554256810224 and parameters: {'C': 5.815944609869444, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.710739582722976}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:43,747] Trial 76 finished with value: 0.801123874444657 and parameters: {'C': 29.228971360744527, 'kernel': 'poly', 'degree': 2, 'gamma': 'auto', 'coef0': 0.6669555319615852}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:47,984] Trial 77 finished with value: 0.7808470692892128 and parameters: {'C': 7.52165403574072, 'kernel': 'poly', 'degree': 5, 'gamma': 'scale', 'coef0': 0.618926280167127}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:51,183] Trial 78 finished with value: 0.6722742812220389 and parameters: {'C': 2.508654210183626, 'kernel': 'sigmoid', 'gamma': 'scale', 'coef0': 0.5738147799744643}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:52:55,906] Trial 79 finished with value: 0.7832922849355312 and parameters: {'C': 88.50845101825033, 'kernel': 'rbf', 'gamma': 'auto', 'coef0': 0.7771147770999827}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:04,269] Trial 80 finished with value: 0.7861680174192781 and parameters: {'C': 4.176415359504796, 'kernel': 'linear', 'gamma': 'scale', 'coef0': 0.7445087698923112}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:07,906] Trial 81 finished with value: 0.8018426782657266 and parameters: {'C': 9.763001308472566, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.511617370154126}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:12,549] Trial 82 finished with value: 0.8016991036933213 and parameters: {'C': 13.56955754278292, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.677969327791657}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:17,782] Trial 83 finished with value: 0.8014116442288296 and parameters: {'C': 18.735615611709235, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.5413751390756032}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:20,687] Trial 84 finished with value: 0.8024182178340722 and parameters: {'C': 6.1102244216619885, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.6972429848404096}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:23,649] Trial 85 finished with value: 0.8024182178340722 and parameters: {'C': 6.136327758948764, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.7047175033490697}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:26,187] Trial 86 finished with value: 0.7996851289636874 and parameters: {'C': 3.202303971322572, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.6952085098438315}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:29,863] Trial 87 finished with value: 0.7884674862554241 and parameters: {'C': 4.90761104592114, 'kernel': 'poly', 'degree': 4, 'gamma': 'auto', 'coef0': 0.7314506552279143}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:33,052] Trial 88 finished with value: 0.8018427817056205 and parameters: {'C': 8.20535397912719, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.6092628349753164}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:37,235] Trial 89 finished with value: 0.8015553222411288 and parameters: {'C': 12.995526252260909, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.7778401353531845}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:39,609] Trial 90 finished with value: 0.7959472249662527 and parameters: {'C': 1.5786764342384911, 'kernel': 'poly', 'degree': 3, 'gamma': 'scale', 'coef0': 0.634709783055582}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:42,614] Trial 91 finished with value: 0.8024182178340722 and parameters: {'C': 6.003907657067011, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.7063553339664718}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:48,436] Trial 92 finished with value: 0.8016992071332151 and parameters: {'C': 22.753789204013408, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.7048495630563489}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:51,221] Trial 93 finished with value: 0.8006925300880792 and parameters: {'C': 5.388444959750523, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.665900389880725}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:53,510] Trial 94 finished with value: 0.8006920128886108 and parameters: {'C': 2.238650601441274, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.7465511380630103}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:53:57,207] Trial 95 finished with value: 0.8018426782657266 and parameters: {'C': 8.888381818319298, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.731488175481844}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:54:00,215] Trial 96 finished with value: 0.6626401998458745 and parameters: {'C': 3.501533774337152, 'kernel': 'sigmoid', 'gamma': 'scale', 'coef0': 0.7999605192869558}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:54:04,183] Trial 97 finished with value: 0.8018429885854077 and parameters: {'C': 12.091077413157793, 'kernel': 'poly', 'degree': 2, 'gamma': 'auto', 'coef0': 0.6509728811921404}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:54:06,229] Trial 98 finished with value: 0.7799839668164821 and parameters: {'C': 0.022248223750924164, 'kernel': 'linear', 'gamma': 'scale', 'coef0': 0.5744494349501424}. Best is trial 16 with value: 0.8028497690704374.
# [I 2025-07-07 23:54:09,247] Trial 99 finished with value: 0.8028496656305437 and parameters: {'C': 6.301944233684189, 'kernel': 'poly', 'degree': 2, 'gamma': 'scale', 'coef0': 0.614635989859625}. Best is trial 16 with value: 0.8028497690704374.
# Best trial:
# {'C': 7.343347632061625, 'kernel': 'poly', 'degree': 2, 'gamma': 'auto', 'coef0': 0.7604473808714275}

# %%
study.best_value
# Out:
# 0.8028497690704374

# %%
train, train_imputers, train_ohe = update_train_df(full_df)
# Out:
# /tmp/ipykernel_155917/3056761461.py:68: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0 1 0 ... 1 0 1]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'Transported'] = df.loc[:, 'Transported'].astype(int)

# %%
test_df = pd.read_csv('dataset/test.csv')
test = update_test_df(test_df, train_imputers, train_ohe)

# %%
X = train.drop('Transported', axis=1)
y = train.loc[:, 'Transported']

# %%
best_params = study.best_trial.params

# %%
best_model = Pipeline([
        ('scaler', StandardScaler()),
        ('svc', SVC(**best_params, random_state=42))
    ])
best_model.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svc',
#                  SVC(C=7.343347632061625, coef0=0.7604473808714275, degree=2,
#                      gamma='auto', kernel='poly', random_state=42))])

# %%
y_pred = best_model.predict(test)
y_pre = y_pred.astype(bool)

# %%
test_df = pd.read_csv('dataset/test.csv')


submission = pd.DataFrame({
    'PassengerId': test_df['PassengerId'],
    'Transported' : y_pred.astype(bool)
})
submission
# Out:
#      PassengerId  Transported
# 0        0013_01         True
# 1        0018_01        False
# 2        0019_01         True
# 3        0021_01         True
# 4        0023_01        False
# ...          ...          ...
# 4272     9266_02         True
# 4273     9269_01        False
# 4274     9271_01         True
# 4275     9273_01         True
# 4276     9277_01         True
#
# [4277 rows x 2 columns]

# %%
submission.to_csv('svc-poly-2-80.3.csv', index=False)

# %%
best_params
# Out:
# {'C': 7.343347632061625,
#  'kernel': 'poly',
#  'degree': 2,
#  'gamma': 'auto',
#  'coef0': 0.7604473808714275}
