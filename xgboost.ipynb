# %%
import pandas as pd

# %%
full_df = pd.read_csv('dataset/train.csv')
df = full_df.copy()

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

def update_train_df(dataframe):
    imputers = {
        'name_imputer': SimpleImputer(strategy='constant', fill_value='Unknown Unknown'),
        'num_imputer': SimpleImputer(strategy='median'),
        'cat_imputer': SimpleImputer(strategy='constant', fill_value='Unknown'),
    }

    num_col = ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']
    cat_cols = ['HomePlanet', 'CryoSleep', 'Cabin', 'Destination', 'VIP']
    
    df = dataframe.copy()

    # Impute Part
    df.loc[:, 'Name'] = imputers['name_imputer'].fit_transform(df.loc[:, 'Name'].to_frame())
    df.loc[:, num_col] = imputers['num_imputer'].fit_transform(df.loc[:, num_col])
    df.loc[:, cat_cols] = imputers['cat_imputer'].fit_transform(df.loc[:, cat_cols])

    # Feature engineering Part
    df.loc[:, 'FirstName'] = df.loc[:, 'Name'].apply(lambda x: x.split()[0])
    df.loc[:, 'LastName'] = df.loc[:, 'Name'].apply(lambda x: x.split()[1])

    df.loc[:, 'PassengerGGGG'] = df.loc[:, 'PassengerId'].apply(lambda x: int(x.split('_')[0]))
    df.loc[:, 'PassengerPP'] = df.loc[:, 'PassengerId'].apply(lambda x: int(x.split('_')[1]))
    
    df.loc[:, 'NumberOfFellows'] = df.groupby('PassengerGGGG')['PassengerGGGG'].transform('count')
    df.loc[:, 'IsAlone'] = df.loc[:, 'NumberOfFellows'].apply(lambda x: 1 if x == 1 else 0)

    df['cabin_deck'] = df['Cabin'].apply(lambda x: x.split('/')[0] if x != 'Unknown' else 'U')
    df['cabin_num'] = df['Cabin'].apply(lambda x: int(x.split('/')[1]) if x != 'Unknown' else -1)
    df['cabin_side'] = df['Cabin'].apply(lambda x: x.split('/')[2] if x != 'Unknown' else 'U')

    df.loc[:, 'TotalSpend'] = df.loc[:, ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']].sum(axis=1)
    df['IsSpendingZero'] = (df['TotalSpend'] == 0).astype(int)

    # Removing unnecessary columns
    df.drop(['Cabin', 'Name', 'PassengerId'], inplace=True, axis=1)
    df.drop(['FirstName', 'LastName', 'PassengerGGGG'], inplace=True, axis=1)


    # std_scalers = {}

    # num_cols = df.select_dtypes('float').columns

    # for num_col in num_cols:
    #     scaler = StandardScaler()
    #     df.loc[:, num_col] = scaler.fit_transform(df.loc[:, num_col])

    #     std_scalers = 

    # Encoding 
    cat_data = df.select_dtypes('object')
    cat_data.loc[:, ['CryoSleep', 'VIP']] = cat_data.loc[:, ['CryoSleep', 'VIP']].astype('str')
    
    one_hot_encoder = OneHotEncoder(drop='first', dtype=int)
    
    cat_data_encoded = one_hot_encoder.fit_transform(cat_data)
    encoded_feature_names = one_hot_encoder.get_feature_names_out(cat_data.columns)
    
    cat_encoded = pd.DataFrame(cat_data_encoded.toarray(), columns = encoded_feature_names, index=cat_data.index)
    
    non_cat = df.drop(cat_data.columns, axis=1)
    df = pd.concat([non_cat, cat_encoded], axis=1)
    
    df.loc[:, 'Transported'] = df.loc[:, 'Transported'].astype(int)
    
    return df, imputers, one_hot_encoder

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

def update_test_df(dataframe, imputers, one_hot_encoder):
    num_col = ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']
    cat_cols = ['HomePlanet', 'CryoSleep', 'Cabin', 'Destination', 'VIP']
    
    df = dataframe.copy()

    # Impute Part
    df.loc[:, 'Name'] = imputers['name_imputer'].transform(df.loc[:, 'Name'].to_frame())
    df.loc[:, num_col] = imputers['num_imputer'].transform(df.loc[:, num_col])
    df.loc[:, cat_cols] = imputers['cat_imputer'].transform(df.loc[:, cat_cols])

    # Feature engineering Part
    df.loc[:, 'FirstName'] = df.loc[:, 'Name'].apply(lambda x: x.split()[0])
    df.loc[:, 'LastName'] = df.loc[:, 'Name'].apply(lambda x: x.split()[1])

    df.loc[:, 'PassengerGGGG'] = df.loc[:, 'PassengerId'].apply(lambda x: int(x.split('_')[0]))
    df.loc[:, 'PassengerPP'] = df.loc[:, 'PassengerId'].apply(lambda x: int(x.split('_')[1]))
    
    df.loc[:, 'NumberOfFellows'] = df.groupby('PassengerGGGG')['PassengerGGGG'].transform('count')
    df.loc[:, 'IsAlone'] = df.loc[:, 'NumberOfFellows'].apply(lambda x: 1 if x == 1 else 0)

    df['cabin_deck'] = df['Cabin'].apply(lambda x: x.split('/')[0] if x != 'Unknown' else 'U')
    df['cabin_num'] = df['Cabin'].apply(lambda x: int(x.split('/')[1]) if x != 'Unknown' else -1)
    df['cabin_side'] = df['Cabin'].apply(lambda x: x.split('/')[2] if x != 'Unknown' else 'U')

    df.loc[:, 'TotalSpend'] = df.loc[:, ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']].sum(axis=1)
    df['IsSpendingZero'] = (df['TotalSpend'] == 0).astype(int)

    # Removing unnecessary columns
    df.drop(['Cabin', 'Name', 'PassengerId'], inplace=True, axis=1)
    df.drop(['FirstName', 'LastName', 'PassengerGGGG'], inplace=True, axis=1)

    # Encoding
    cat_data = df.select_dtypes('object')
    cat_data.loc[:, ['CryoSleep', 'VIP']] = cat_data.loc[:, ['CryoSleep', 'VIP']].astype('str')
        
    cat_data_encoded = one_hot_encoder.transform(cat_data)
    encoded_feature_names = one_hot_encoder.get_feature_names_out(cat_data.columns)
    
    cat_encoded = pd.DataFrame(cat_data_encoded.toarray(), columns = encoded_feature_names, index=cat_data.index)
    
    non_cat = df.drop(cat_data.columns, axis=1)
    df = pd.concat([non_cat, cat_encoded], axis=1)
    
    return df

# %%
df_train_updated, train_imputers, train_ohe = update_train_df(df_train)
# Out:
# /tmp/ipykernel_131002/3056761461.py:68: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0 0 0 ... 0 1 1]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'Transported'] = df.loc[:, 'Transported'].astype(int)

# %%
df_test_updated = update_test_df(df_test, train_imputers, train_ohe)

# %%
X_train = df_train_updated.drop('Transported', axis=1)
y_train = df_train_updated.loc[:, 'Transported']

X_test = df_test_updated.drop('Transported', axis=1)
y_test = df_test_updated.loc[:, 'Transported']

# %%
import optuna
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score

def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.5),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 0.5),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 0.5),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 0.5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
        'use_label_encoder': False,
        'eval_metric': 'logloss'
    }
    
    model = XGBClassifier(**params, random_state=42, verbosity=0)
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

print("Best trial:")
print(study.best_trial.params)
# Out:
# [I 2025-07-07 23:19:50,353] A new study created in memory with name: no-name-003cdbae-4ef8-4d87-8aeb-f66507147e72
# [I 2025-07-07 23:19:51,136] Trial 0 finished with value: 0.800834035862611 and parameters: {'n_estimators': 322, 'max_depth': 6, 'learning_rate': 0.19263048566039379, 'subsample': 0.7956179418630394, 'colsample_bytree': 0.87274067183877, 'gamma': 0.026700277670561157, 'reg_alpha': 0.14943824383421894, 'reg_lambda': 0.04856864590458354, 'min_child_weight': 14}. Best is trial 0 with value: 0.800834035862611.
# [I 2025-07-07 23:19:51,514] Trial 1 finished with value: 0.7896172206734972 and parameters: {'n_estimators': 147, 'max_depth': 7, 'learning_rate': 0.46906416694649994, 'subsample': 0.6902948675415796, 'colsample_bytree': 0.9079829110382963, 'gamma': 0.0715656458103956, 'reg_alpha': 0.32849014788082337, 'reg_lambda': 0.016414616593983633, 'min_child_weight': 13}. Best is trial 0 with value: 0.800834035862611.
# [I 2025-07-07 23:19:52,005] Trial 2 finished with value: 0.7880345903004412 and parameters: {'n_estimators': 164, 'max_depth': 11, 'learning_rate': 0.4594341562267825, 'subsample': 0.8409647846388781, 'colsample_bytree': 0.7211068949774434, 'gamma': 0.48750221248439213, 'reg_alpha': 0.394343403460027, 'reg_lambda': 0.4491332196670756, 'min_child_weight': 6}. Best is trial 0 with value: 0.800834035862611.
# [I 2025-07-07 23:19:52,504] Trial 3 finished with value: 0.8090297855173805 and parameters: {'n_estimators': 467, 'max_depth': 3, 'learning_rate': 0.1987776454707174, 'subsample': 0.9907590115724726, 'colsample_bytree': 0.9933937601952432, 'gamma': 0.2182689500729999, 'reg_alpha': 0.3143693754594963, 'reg_lambda': 0.07151999696437811, 'min_child_weight': 8}. Best is trial 3 with value: 0.8090297855173805.
# [I 2025-07-07 23:19:54,300] Trial 4 finished with value: 0.8071614541580251 and parameters: {'n_estimators': 316, 'max_depth': 12, 'learning_rate': 0.02337638635633741, 'subsample': 0.8155805367188147, 'colsample_bytree': 0.7914351791934254, 'gamma': 0.11618724928143975, 'reg_alpha': 0.042592025574491155, 'reg_lambda': 0.3958252680791743, 'min_child_weight': 1}. Best is trial 3 with value: 0.8090297855173805.
# [I 2025-07-07 23:19:55,515] Trial 5 finished with value: 0.7794069790896254 and parameters: {'n_estimators': 806, 'max_depth': 5, 'learning_rate': 0.4271061946679916, 'subsample': 0.6240510303759895, 'colsample_bytree': 0.7095074043994707, 'gamma': 0.18591800960161137, 'reg_alpha': 0.4192906148201024, 'reg_lambda': 0.4788900482790742, 'min_child_weight': 12}. Best is trial 3 with value: 0.8090297855173805.
# [I 2025-07-07 23:19:56,467] Trial 6 finished with value: 0.8021280689323451 and parameters: {'n_estimators': 581, 'max_depth': 6, 'learning_rate': 0.1518688230520798, 'subsample': 0.9824911153119305, 'colsample_bytree': 0.8686239081650083, 'gamma': 0.12061277255596642, 'reg_alpha': 0.24560139275386156, 'reg_lambda': 0.08044946354248667, 'min_child_weight': 16}. Best is trial 3 with value: 0.8090297855173805.
# [I 2025-07-07 23:19:57,730] Trial 7 finished with value: 0.794362629235217 and parameters: {'n_estimators': 613, 'max_depth': 12, 'learning_rate': 0.17143949340250164, 'subsample': 0.7388594593281589, 'colsample_bytree': 0.8301324049598451, 'gamma': 0.4466052552452929, 'reg_alpha': 0.25267324472230906, 'reg_lambda': 0.29840218326058116, 'min_child_weight': 12}. Best is trial 3 with value: 0.8090297855173805.
# [I 2025-07-07 23:19:58,507] Trial 8 finished with value: 0.8008336221030365 and parameters: {'n_estimators': 335, 'max_depth': 11, 'learning_rate': 0.17572264156646042, 'subsample': 0.7829563916161223, 'colsample_bytree': 0.7729060922558477, 'gamma': 0.3502494976369798, 'reg_alpha': 0.20053206989469302, 'reg_lambda': 0.4239734654101642, 'min_child_weight': 17}. Best is trial 3 with value: 0.8090297855173805.
# [I 2025-07-07 23:19:59,326] Trial 9 finished with value: 0.7936442391737221 and parameters: {'n_estimators': 530, 'max_depth': 5, 'learning_rate': 0.36829394183273156, 'subsample': 0.8273629314912587, 'colsample_bytree': 0.7914637130437242, 'gamma': 0.24598390483205218, 'reg_alpha': 0.1925719343963116, 'reg_lambda': 0.3445859979638614, 'min_child_weight': 6}. Best is trial 3 with value: 0.8090297855173805.
# [I 2025-07-07 23:19:59,992] Trial 10 finished with value: 0.8054351457726702 and parameters: {'n_estimators': 989, 'max_depth': 3, 'learning_rate': 0.3097396962300468, 'subsample': 0.9999520914910119, 'colsample_bytree': 0.994695773692408, 'gamma': 0.33244839861656844, 'reg_alpha': 0.4712264551418069, 'reg_lambda': 0.1678489401107969, 'min_child_weight': 20}. Best is trial 3 with value: 0.8090297855173805.
# [I 2025-07-07 23:20:01,279] Trial 11 finished with value: 0.8037104924256138 and parameters: {'n_estimators': 382, 'max_depth': 9, 'learning_rate': 0.03130368198283047, 'subsample': 0.9064354270779292, 'colsample_bytree': 0.6473822278788172, 'gamma': 0.1849199919751975, 'reg_alpha': 0.00026750507674917767, 'reg_lambda': 0.20253739468641485, 'min_child_weight': 1}. Best is trial 3 with value: 0.8090297855173805.
# [I 2025-07-07 23:20:02,946] Trial 12 finished with value: 0.8037104924256138 and parameters: {'n_estimators': 447, 'max_depth': 9, 'learning_rate': 0.02714389706403736, 'subsample': 0.8932168860658426, 'colsample_bytree': 0.9638929707533894, 'gamma': 0.15207782589028462, 'reg_alpha': 0.03593248045375967, 'reg_lambda': 0.35166234184329626, 'min_child_weight': 1}. Best is trial 3 with value: 0.8090297855173805.
# [I 2025-07-07 23:20:03,649] Trial 13 finished with value: 0.8096052216458322 and parameters: {'n_estimators': 715, 'max_depth': 3, 'learning_rate': 0.10293760222444995, 'subsample': 0.9259618605702769, 'colsample_bytree': 0.6404924248420307, 'gamma': 0.26788989235186494, 'reg_alpha': 0.10261424581162237, 'reg_lambda': 0.13558609290377333, 'min_child_weight': 7}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:04,390] Trial 14 finished with value: 0.8083109816963108 and parameters: {'n_estimators': 738, 'max_depth': 3, 'learning_rate': 0.10516549140078572, 'subsample': 0.931527702314516, 'colsample_bytree': 0.6004179843135424, 'gamma': 0.2953436839235766, 'reg_alpha': 0.11035021364184712, 'reg_lambda': 0.14411329474608597, 'min_child_weight': 8}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:05,167] Trial 15 finished with value: 0.7959447424088049 and parameters: {'n_estimators': 744, 'max_depth': 4, 'learning_rate': 0.25848008524708654, 'subsample': 0.9501487764939949, 'colsample_bytree': 0.701597587580496, 'gamma': 0.2595674061143129, 'reg_alpha': 0.333112469927798, 'reg_lambda': 0.10264815418319949, 'min_child_weight': 9}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:06,123] Trial 16 finished with value: 0.8024145974377938 and parameters: {'n_estimators': 901, 'max_depth': 3, 'learning_rate': 0.11333769121836942, 'subsample': 0.8711618326695593, 'colsample_bytree': 0.932120409791371, 'gamma': 0.38005993746336497, 'reg_alpha': 0.309064274239626, 'reg_lambda': 0.23573259792172294, 'min_child_weight': 4}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:06,907] Trial 17 finished with value: 0.7996829567259205 and parameters: {'n_estimators': 668, 'max_depth': 4, 'learning_rate': 0.23914060629401315, 'subsample': 0.9423876821642074, 'colsample_bytree': 0.6456810526405259, 'gamma': 0.23711101004232538, 'reg_alpha': 0.09931569379281957, 'reg_lambda': 0.12400567892171245, 'min_child_weight': 9}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:07,525] Trial 18 finished with value: 0.8058670073287164 and parameters: {'n_estimators': 501, 'max_depth': 8, 'learning_rate': 0.09997408388422134, 'subsample': 0.9731682703015395, 'colsample_bytree': 0.7336223703817332, 'gamma': 0.40418025809865576, 'reg_alpha': 0.2715087961017982, 'reg_lambda': 0.00044851541431448205, 'min_child_weight': 4}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:08,861] Trial 19 finished with value: 0.7930670445670781 and parameters: {'n_estimators': 858, 'max_depth': 4, 'learning_rate': 0.24487572894018006, 'subsample': 0.8814541692222368, 'colsample_bytree': 0.9998003805952386, 'gamma': 0.2127999859419382, 'reg_alpha': 0.38504611511919856, 'reg_lambda': 0.17836253535596597, 'min_child_weight': 7}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:09,610] Trial 20 finished with value: 0.7934994233225928 and parameters: {'n_estimators': 675, 'max_depth': 5, 'learning_rate': 0.30750497493454154, 'subsample': 0.9237484796714066, 'colsample_bytree': 0.6645584667126558, 'gamma': 0.28925273609337177, 'reg_alpha': 0.1783688888035327, 'reg_lambda': 0.07289120351181747, 'min_child_weight': 4}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:10,343] Trial 21 finished with value: 0.8077353386880718 and parameters: {'n_estimators': 730, 'max_depth': 3, 'learning_rate': 0.09096857621014232, 'subsample': 0.9496517489440982, 'colsample_bytree': 0.6121959564578906, 'gamma': 0.3133888982421221, 'reg_alpha': 0.12359289298864767, 'reg_lambda': 0.13126116280209396, 'min_child_weight': 9}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:11,117] Trial 22 finished with value: 0.8087427398124636 and parameters: {'n_estimators': 775, 'max_depth': 3, 'learning_rate': 0.0744156526378992, 'subsample': 0.8617382296623751, 'colsample_bytree': 0.6039809496665084, 'gamma': 0.26987737238359827, 'reg_alpha': 0.0845073984601643, 'reg_lambda': 0.14487956646644295, 'min_child_weight': 8}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:12,208] Trial 23 finished with value: 0.8070165348670022 and parameters: {'n_estimators': 922, 'max_depth': 4, 'learning_rate': 0.060612658172516404, 'subsample': 0.859326584640016, 'colsample_bytree': 0.6735850346269384, 'gamma': 0.26257619931280796, 'reg_alpha': 0.06712307818849944, 'reg_lambda': 0.2237768723761689, 'min_child_weight': 11}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:13,453] Trial 24 finished with value: 0.7979572689799275 and parameters: {'n_estimators': 829, 'max_depth': 6, 'learning_rate': 0.13889521815937322, 'subsample': 0.9064573762381153, 'colsample_bytree': 0.6263041273564516, 'gamma': 0.21002972205799725, 'reg_alpha': 0.14735841727822652, 'reg_lambda': 0.27351776854371823, 'min_child_weight': 6}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:13,901] Trial 25 finished with value: 0.8067284547631484 and parameters: {'n_estimators': 448, 'max_depth': 3, 'learning_rate': 0.20440196226720952, 'subsample': 0.9701488985777421, 'colsample_bytree': 0.7574911049552355, 'gamma': 0.36034219918968297, 'reg_alpha': 0.07493865910116126, 'reg_lambda': 0.05880359954374435, 'min_child_weight': 10}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:14,744] Trial 26 finished with value: 0.8088860040651878 and parameters: {'n_estimators': 643, 'max_depth': 4, 'learning_rate': 0.06741900150535977, 'subsample': 0.8509354394062912, 'colsample_bytree': 0.8315361725401054, 'gamma': 0.15465814861092225, 'reg_alpha': 0.009693870963667958, 'reg_lambda': 0.18538559064151217, 'min_child_weight': 3}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:15,824] Trial 27 finished with value: 0.7929247112733968 and parameters: {'n_estimators': 659, 'max_depth': 5, 'learning_rate': 0.1325815478965253, 'subsample': 0.7392486578045375, 'colsample_bytree': 0.8304938574302003, 'gamma': 0.14281235967493697, 'reg_alpha': 0.0035450306057372982, 'reg_lambda': 0.17861445692889566, 'min_child_weight': 3}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:16,710] Trial 28 finished with value: 0.8085992686799518 and parameters: {'n_estimators': 599, 'max_depth': 4, 'learning_rate': 0.06426237404725597, 'subsample': 0.7737117189626018, 'colsample_bytree': 0.9159888788408211, 'gamma': 0.07538988083772641, 'reg_alpha': 0.043647276560405956, 'reg_lambda': 0.2657946489159839, 'min_child_weight': 5}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:17,271] Trial 29 finished with value: 0.7981011538720139 and parameters: {'n_estimators': 269, 'max_depth': 6, 'learning_rate': 0.21142167663838018, 'subsample': 0.9957175420411032, 'colsample_bytree': 0.8689544521829762, 'gamma': 0.03887424082218657, 'reg_alpha': 0.21816295718349105, 'reg_lambda': 0.1005346878559267, 'min_child_weight': 3}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:18,011] Trial 30 finished with value: 0.7959439148896555 and parameters: {'n_estimators': 471, 'max_depth': 4, 'learning_rate': 0.3164705866887293, 'subsample': 0.9150660400084598, 'colsample_bytree': 0.8318257442375834, 'gamma': 0.008155755647903495, 'reg_alpha': 0.16268076968379547, 'reg_lambda': 0.03218159782905847, 'min_child_weight': 15}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:18,819] Trial 31 finished with value: 0.807447982663474 and parameters: {'n_estimators': 785, 'max_depth': 3, 'learning_rate': 0.06626571544849105, 'subsample': 0.8500055625724692, 'colsample_bytree': 0.6764205090347575, 'gamma': 0.19174058788894893, 'reg_alpha': 0.08144921249707054, 'reg_lambda': 0.15260795562139645, 'min_child_weight': 7}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:19,500] Trial 32 finished with value: 0.8062968000868895 and parameters: {'n_estimators': 542, 'max_depth': 3, 'learning_rate': 0.08006917654212982, 'subsample': 0.8743439605779472, 'colsample_bytree': 0.9503777294127119, 'gamma': 0.2689022511413491, 'reg_alpha': 0.1307052426776475, 'reg_lambda': 0.21137726131550127, 'min_child_weight': 8}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:20,814] Trial 33 finished with value: 0.7983885098966119 and parameters: {'n_estimators': 710, 'max_depth': 7, 'learning_rate': 0.13469846862427698, 'subsample': 0.8221618436350546, 'colsample_bytree': 0.6275271354175431, 'gamma': 0.22089917672830622, 'reg_alpha': 0.2881993597062409, 'reg_lambda': 0.043510532909219246, 'min_child_weight': 10}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:21,780] Trial 34 finished with value: 0.8094619573931077 and parameters: {'n_estimators': 629, 'max_depth': 4, 'learning_rate': 0.04408322819447319, 'subsample': 0.8033258931527604, 'colsample_bytree': 0.7435829366747851, 'gamma': 0.16232430543032794, 'reg_alpha': 0.35209643503945015, 'reg_lambda': 0.10760387197955341, 'min_child_weight': 7}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:22,564] Trial 35 finished with value: 0.8065848801907431 and parameters: {'n_estimators': 407, 'max_depth': 5, 'learning_rate': 0.017588737645156872, 'subsample': 0.7345693448053079, 'colsample_bytree': 0.8976305799565567, 'gamma': 0.09115498887447684, 'reg_alpha': 0.3476941595972998, 'reg_lambda': 0.09458730812652436, 'min_child_weight': 2}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:23,990] Trial 36 finished with value: 0.8021279654924515 and parameters: {'n_estimators': 616, 'max_depth': 7, 'learning_rate': 0.045455398933026275, 'subsample': 0.6735149472896631, 'colsample_bytree': 0.7416289460964076, 'gamma': 0.16300688084159265, 'reg_alpha': 0.36597161953593854, 'reg_lambda': 0.12018841679718646, 'min_child_weight': 5}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:24,741] Trial 37 finished with value: 0.8051473759884974 and parameters: {'n_estimators': 566, 'max_depth': 4, 'learning_rate': 0.16811533646937868, 'subsample': 0.7634346622777565, 'colsample_bytree': 0.6957344208320502, 'gamma': 0.11347979430979815, 'reg_alpha': 0.4071906468650337, 'reg_lambda': 0.19074238932877652, 'min_child_weight': 6}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:25,169] Trial 38 finished with value: 0.7982444181247381 and parameters: {'n_estimators': 185, 'max_depth': 5, 'learning_rate': 0.012960766049053878, 'subsample': 0.802002805219436, 'colsample_bytree': 0.900788838701253, 'gamma': 0.17055826869971918, 'reg_alpha': 0.3096545978609435, 'reg_lambda': 0.026688256489892925, 'min_child_weight': 13}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:26,534] Trial 39 finished with value: 0.8005454385592892 and parameters: {'n_estimators': 635, 'max_depth': 6, 'learning_rate': 0.11516078397334059, 'subsample': 0.8360713001305422, 'colsample_bytree': 0.8094785768417438, 'gamma': 0.13378335468166844, 'reg_alpha': 0.4426668686957443, 'reg_lambda': 0.06330606614631065, 'min_child_weight': 11}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:27,343] Trial 40 finished with value: 0.8016964142560863 and parameters: {'n_estimators': 501, 'max_depth': 4, 'learning_rate': 0.15940961429877973, 'subsample': 0.7981834436196578, 'colsample_bytree': 0.8505441277856982, 'gamma': 0.04778052123676374, 'reg_alpha': 0.22352358380732615, 'reg_lambda': 0.08618880289982087, 'min_child_weight': 7}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:28,223] Trial 41 finished with value: 0.8080236256717128 and parameters: {'n_estimators': 797, 'max_depth': 3, 'learning_rate': 0.07594776647384124, 'subsample': 0.8453070991338116, 'colsample_bytree': 0.761057255693479, 'gamma': 0.233329962960801, 'reg_alpha': 0.022357222443453104, 'reg_lambda': 0.15404447325165033, 'min_child_weight': 8}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:28,937] Trial 42 finished with value: 0.8078792235801581 and parameters: {'n_estimators': 700, 'max_depth': 3, 'learning_rate': 0.04045509121441995, 'subsample': 0.8917353095827343, 'colsample_bytree': 0.6520573017955306, 'gamma': 0.28787258969956425, 'reg_alpha': 0.36334409770337717, 'reg_lambda': 0.11971943056239626, 'min_child_weight': 5}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:29,642] Trial 43 finished with value: 0.8065856042699988 and parameters: {'n_estimators': 562, 'max_depth': 4, 'learning_rate': 0.05021122634423554, 'subsample': 0.8166919016201287, 'colsample_bytree': 0.6902672331526565, 'gamma': 0.19436824201184597, 'reg_alpha': 0.061234619521340454, 'reg_lambda': 0.15860787006831167, 'min_child_weight': 7}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:30,415] Trial 44 finished with value: 0.8084541425091414 and parameters: {'n_estimators': 768, 'max_depth': 3, 'learning_rate': 0.12192515126968409, 'subsample': 0.9572258589037027, 'colsample_bytree': 0.8002035360366936, 'gamma': 0.32710736029597665, 'reg_alpha': 0.25266964249276036, 'reg_lambda': 0.19463864766539804, 'min_child_weight': 12}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:31,894] Trial 45 finished with value: 0.7999704161904122 and parameters: {'n_estimators': 863, 'max_depth': 5, 'learning_rate': 0.08798972698721308, 'subsample': 0.605643905535542, 'colsample_bytree': 0.9777756449508841, 'gamma': 0.17682489810889812, 'reg_alpha': 0.09786993452049408, 'reg_lambda': 0.2436054160784895, 'min_child_weight': 9}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:32,836] Trial 46 finished with value: 0.7949379619237751 and parameters: {'n_estimators': 371, 'max_depth': 10, 'learning_rate': 0.1894018523660972, 'subsample': 0.8590260935108368, 'colsample_bytree': 0.7128547292697571, 'gamma': 0.10851298109521601, 'reg_alpha': 0.028244717102321414, 'reg_lambda': 0.14058501599749912, 'min_child_weight': 8}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:33,519] Trial 47 finished with value: 0.7919177239085797 and parameters: {'n_estimators': 653, 'max_depth': 3, 'learning_rate': 0.48450115354601875, 'subsample': 0.9315145159449338, 'colsample_bytree': 0.6309768181860765, 'gamma': 0.2066827090593415, 'reg_alpha': 0.4924819316463893, 'reg_lambda': 0.10856195515178826, 'min_child_weight': 20}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:34,038] Trial 48 finished with value: 0.8078797407796265 and parameters: {'n_estimators': 598, 'max_depth': 4, 'learning_rate': 0.14661507307847252, 'subsample': 0.9860928581872718, 'colsample_bytree': 0.6011151393195, 'gamma': 0.48873169566209185, 'reg_alpha': 0.3159711471508512, 'reg_lambda': 0.4812419664932389, 'min_child_weight': 3}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:34,566] Trial 49 finished with value: 0.7888975893332782 and parameters: {'n_estimators': 294, 'max_depth': 5, 'learning_rate': 0.42461816974533323, 'subsample': 0.8924046160491289, 'colsample_bytree': 0.7789029283491506, 'gamma': 0.24209290946567358, 'reg_alpha': 0.27671587877410253, 'reg_lambda': 0.33333325172366346, 'min_child_weight': 6}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:35,334] Trial 50 finished with value: 0.8051471691087102 and parameters: {'n_estimators': 694, 'max_depth': 3, 'learning_rate': 0.03673543425502378, 'subsample': 0.7554697230346953, 'colsample_bytree': 0.883360595735153, 'gamma': 0.14782948558336512, 'reg_alpha': 0.014256175670395277, 'reg_lambda': 0.08060377849319439, 'min_child_weight': 13}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:36,226] Trial 51 finished with value: 0.8085991652400581 and parameters: {'n_estimators': 617, 'max_depth': 4, 'learning_rate': 0.06924798314301099, 'subsample': 0.7689176000691913, 'colsample_bytree': 0.9258497179319599, 'gamma': 0.08191336693178483, 'reg_alpha': 0.04874850686716488, 'reg_lambda': 0.27006779804716113, 'min_child_weight': 6}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:36,949] Trial 52 finished with value: 0.808455487227759 and parameters: {'n_estimators': 522, 'max_depth': 4, 'learning_rate': 0.10375567211037182, 'subsample': 0.7831494583413905, 'colsample_bytree': 0.9309968606172001, 'gamma': 0.27480448832097476, 'reg_alpha': 0.041926742263012344, 'reg_lambda': 0.3071324066944906, 'min_child_weight': 5}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:37,614] Trial 53 finished with value: 0.8085982342810152 and parameters: {'n_estimators': 594, 'max_depth': 3, 'learning_rate': 0.05726512353851898, 'subsample': 0.8003924681520681, 'colsample_bytree': 0.9567614918439942, 'gamma': 0.09757194837101586, 'reg_alpha': 0.08924785623651744, 'reg_lambda': 0.22156686722102137, 'min_child_weight': 2}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:38,688] Trial 54 finished with value: 0.8034218951222918 and parameters: {'n_estimators': 760, 'max_depth': 4, 'learning_rate': 0.08811857295310212, 'subsample': 0.7112423646389285, 'colsample_bytree': 0.9801880670025538, 'gamma': 0.05844868025335262, 'reg_alpha': 0.054427012012995254, 'reg_lambda': 0.2687821828981214, 'min_child_weight': 5}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:40,394] Trial 55 finished with value: 0.7916307816435565 and parameters: {'n_estimators': 835, 'max_depth': 8, 'learning_rate': 0.2671385017762941, 'subsample': 0.8352014228364767, 'colsample_bytree': 0.850541103571616, 'gamma': 0.3144203931098163, 'reg_alpha': 0.13862983468755838, 'reg_lambda': 0.40567435783888156, 'min_child_weight': 18}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:41,529] Trial 56 finished with value: 0.8024149077574748 and parameters: {'n_estimators': 638, 'max_depth': 5, 'learning_rate': 0.10171966812428088, 'subsample': 0.7763986412922896, 'colsample_bytree': 0.9152505762765416, 'gamma': 0.1312850037747993, 'reg_alpha': 0.11548353170144611, 'reg_lambda': 0.13492450799612188, 'min_child_weight': 8}. Best is trial 13 with value: 0.8096052216458322.
# [I 2025-07-07 23:20:42,552] Trial 57 finished with value: 0.80989257767043 and parameters: {'n_estimators': 731, 'max_depth': 4, 'learning_rate': 0.026745430757478754, 'subsample': 0.8112736099258752, 'colsample_bytree': 0.9442956817953684, 'gamma': 0.22713931629140605, 'reg_alpha': 0.32833785170093344, 'reg_lambda': 0.17189784313606132, 'min_child_weight': 4}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:20:46,189] Trial 58 finished with value: 0.8057223983573746 and parameters: {'n_estimators': 731, 'max_depth': 12, 'learning_rate': 0.011952671726411512, 'subsample': 0.8610964972926192, 'colsample_bytree': 0.9811641099730445, 'gamma': 0.2510930138850812, 'reg_alpha': 0.3460889479168723, 'reg_lambda': 0.1810691392908328, 'min_child_weight': 2}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:20:47,051] Trial 59 finished with value: 0.8084539356293542 and parameters: {'n_estimators': 683, 'max_depth': 3, 'learning_rate': 0.03304618438164265, 'subsample': 0.8121886583232858, 'colsample_bytree': 0.9448531719323351, 'gamma': 0.22521766584997166, 'reg_alpha': 0.3857287837599559, 'reg_lambda': 0.16432452434703923, 'min_child_weight': 4}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:20:48,241] Trial 60 finished with value: 0.7956567657448448 and parameters: {'n_estimators': 917, 'max_depth': 4, 'learning_rate': 0.28466407680265793, 'subsample': 0.9054408305903833, 'colsample_bytree': 0.7295369619459426, 'gamma': 0.19991758273159504, 'reg_alpha': 0.29364534492248096, 'reg_lambda': 0.11063374197409279, 'min_child_weight': 10}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:20:49,297] Trial 61 finished with value: 0.8078792235801581 and parameters: {'n_estimators': 732, 'max_depth': 4, 'learning_rate': 0.05101061554306756, 'subsample': 0.7896627174909514, 'colsample_bytree': 0.9725079977851446, 'gamma': 0.15945101103934395, 'reg_alpha': 0.36473312868062757, 'reg_lambda': 0.2038513030378099, 'min_child_weight': 7}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:20:49,884] Trial 62 finished with value: 0.8078790167003709 and parameters: {'n_estimators': 475, 'max_depth': 3, 'learning_rate': 0.07334544527380449, 'subsample': 0.8330969134946988, 'colsample_bytree': 0.9944456418613153, 'gamma': 0.29841226089037587, 'reg_alpha': 0.32434070238153717, 'reg_lambda': 0.2529018033304977, 'min_child_weight': 4}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:20:51,012] Trial 63 finished with value: 0.8090298889572741 and parameters: {'n_estimators': 817, 'max_depth': 4, 'learning_rate': 0.027214236336444205, 'subsample': 0.9644398024309191, 'colsample_bytree': 0.9146940468477801, 'gamma': 0.25316174336550357, 'reg_alpha': 0.3413659704459064, 'reg_lambda': 0.051772257185115675, 'min_child_weight': 5}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:20:52,310] Trial 64 finished with value: 0.8087418088534205 and parameters: {'n_estimators': 821, 'max_depth': 5, 'learning_rate': 0.028817634770045855, 'subsample': 0.966722909597406, 'colsample_bytree': 0.6135514996028651, 'gamma': 0.25361898473742767, 'reg_alpha': 0.4240788870434962, 'reg_lambda': 0.0060231722723009945, 'min_child_weight': 3}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:20:53,075] Trial 65 finished with value: 0.8015518052847442 and parameters: {'n_estimators': 867, 'max_depth': 3, 'learning_rate': 0.3425024840431312, 'subsample': 0.9875531404153572, 'colsample_bytree': 0.8824061405355486, 'gamma': 0.27518304665139137, 'reg_alpha': 0.29312493675257795, 'reg_lambda': 0.0704692359742774, 'min_child_weight': 9}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:20:53,978] Trial 66 finished with value: 0.8025586892096674 and parameters: {'n_estimators': 999, 'max_depth': 3, 'learning_rate': 0.23383601015576738, 'subsample': 0.9392326713382623, 'colsample_bytree': 0.9383134368611293, 'gamma': 0.3502042028850221, 'reg_alpha': 0.3329226396655955, 'reg_lambda': 0.059043020183440015, 'min_child_weight': 1}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:20:54,995] Trial 67 finished with value: 0.8029902404460328 and parameters: {'n_estimators': 792, 'max_depth': 4, 'learning_rate': 0.12350996722371824, 'subsample': 0.9621002509746907, 'colsample_bytree': 0.9634317046909824, 'gamma': 0.18183602436967966, 'reg_alpha': 0.3481098465192457, 'reg_lambda': 0.0479605718076504, 'min_child_weight': 6}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:20:56,380] Trial 68 finished with value: 0.8085980274012279 and parameters: {'n_estimators': 956, 'max_depth': 5, 'learning_rate': 0.027670829523477825, 'subsample': 0.9188183043619338, 'colsample_bytree': 0.6582175381048349, 'gamma': 0.22028860417119633, 'reg_alpha': 0.23609611374891, 'reg_lambda': 0.029129266541141022, 'min_child_weight': 7}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:20:57,754] Trial 69 finished with value: 0.8009764725961862 and parameters: {'n_estimators': 764, 'max_depth': 6, 'learning_rate': 0.05566219213470454, 'subsample': 0.8742030201421596, 'colsample_bytree': 0.8540168617739459, 'gamma': 0.2384021317086385, 'reg_alpha': 0.17816393411615164, 'reg_lambda': 0.17099716145660865, 'min_child_weight': 8}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:20:58,408] Trial 70 finished with value: 0.8048597096442185 and parameters: {'n_estimators': 703, 'max_depth': 4, 'learning_rate': 0.09419162550378016, 'subsample': 0.9976380389519794, 'colsample_bytree': 0.7493566942682475, 'gamma': 0.45890206997228783, 'reg_alpha': 0.2625289591825046, 'reg_lambda': 0.09086687084415723, 'min_child_weight': 5}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:20:59,668] Trial 71 finished with value: 0.8085980274012277 and parameters: {'n_estimators': 835, 'max_depth': 5, 'learning_rate': 0.027778386663591916, 'subsample': 0.9777249165960124, 'colsample_bytree': 0.6141956910654979, 'gamma': 0.2577708452503043, 'reg_alpha': 0.4525185223150907, 'reg_lambda': 0.0034209705137812213, 'min_child_weight': 3}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:21:00,578] Trial 72 finished with value: 0.805578616905182 and parameters: {'n_estimators': 807, 'max_depth': 3, 'learning_rate': 0.04053968857191936, 'subsample': 0.9493903659291468, 'colsample_bytree': 0.6427883989503553, 'gamma': 0.28458430950582536, 'reg_alpha': 0.42132942887365893, 'reg_lambda': 0.012608911044651602, 'min_child_weight': 2}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:21:01,769] Trial 73 finished with value: 0.8080218671935204 and parameters: {'n_estimators': 898, 'max_depth': 4, 'learning_rate': 0.010476826473909736, 'subsample': 0.973414982150789, 'colsample_bytree': 0.6144114305559636, 'gamma': 0.2592461765299478, 'reg_alpha': 0.37511941824173956, 'reg_lambda': 0.045302680308942175, 'min_child_weight': 4}. Best is trial 57 with value: 0.80989257767043.
# [I 2025-07-07 23:21:02,666] Trial 74 finished with value: 0.8101804508944964 and parameters: {'n_estimators': 817, 'max_depth': 3, 'learning_rate': 0.0816525631511912, 'subsample': 0.9618214514489957, 'colsample_bytree': 0.6390303515291257, 'gamma': 0.2256057696902123, 'reg_alpha': 0.40266566984067254, 'reg_lambda': 0.14568814833206822, 'min_child_weight': 3}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:03,911] Trial 75 finished with value: 0.8009768863557609 and parameters: {'n_estimators': 751, 'max_depth': 11, 'learning_rate': 0.07733045849282855, 'subsample': 0.9342163656712863, 'colsample_bytree': 0.8159028797436126, 'gamma': 0.3016969816445737, 'reg_alpha': 0.4039972291001323, 'reg_lambda': 0.14646107375745387, 'min_child_weight': 6}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:04,614] Trial 76 finished with value: 0.8081664761648625 and parameters: {'n_estimators': 664, 'max_depth': 3, 'learning_rate': 0.11034553519560321, 'subsample': 0.9522651953962538, 'colsample_bytree': 0.6702673333188068, 'gamma': 0.21401902010396298, 'reg_alpha': 0.3949528810483022, 'reg_lambda': 0.12781341173376698, 'min_child_weight': 4}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:05,405] Trial 77 finished with value: 0.8006898406508439 and parameters: {'n_estimators': 717, 'max_depth': 3, 'learning_rate': 0.18225286394359735, 'subsample': 0.8537328814895644, 'colsample_bytree': 0.7836530487478993, 'gamma': 0.23065583063171222, 'reg_alpha': 0.34231393316457603, 'reg_lambda': 0.11034379623858485, 'min_child_weight': 1}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:06,563] Trial 78 finished with value: 0.8067285582030422 and parameters: {'n_estimators': 888, 'max_depth': 4, 'learning_rate': 0.0642870553680667, 'subsample': 0.8236090018052027, 'colsample_bytree': 0.6849350142923121, 'gamma': 0.2011200211432938, 'reg_alpha': 0.3032776711354741, 'reg_lambda': 0.18660316048310374, 'min_child_weight': 4}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:07,053] Trial 79 finished with value: 0.8068732706142778 and parameters: {'n_estimators': 428, 'max_depth': 3, 'learning_rate': 0.08578564188951644, 'subsample': 0.808649778939064, 'colsample_bytree': 0.62715026465518, 'gamma': 0.18539986610413461, 'reg_alpha': 0.4380736080050489, 'reg_lambda': 0.09531100018271403, 'min_child_weight': 7}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:07,813] Trial 80 finished with value: 0.7979576827395022 and parameters: {'n_estimators': 775, 'max_depth': 9, 'learning_rate': 0.21578146274284998, 'subsample': 0.9867468017406367, 'colsample_bytree': 0.6370257498852353, 'gamma': 0.17307326086735267, 'reg_alpha': 0.32043366809004115, 'reg_lambda': 0.14736602093293286, 'min_child_weight': 3}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:08,972] Trial 81 finished with value: 0.8074477757836865 and parameters: {'n_estimators': 942, 'max_depth': 4, 'learning_rate': 0.02697839819205887, 'subsample': 0.969268057547974, 'colsample_bytree': 0.600682128743213, 'gamma': 0.24859226266877826, 'reg_alpha': 0.41283486363609095, 'reg_lambda': 0.018967018171458204, 'min_child_weight': 3}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:09,797] Trial 82 finished with value: 0.806728971962617 and parameters: {'n_estimators': 823, 'max_depth': 3, 'learning_rate': 0.04621098263973737, 'subsample': 0.9677934833100212, 'colsample_bytree': 0.6151502035967417, 'gamma': 0.26353180355426564, 'reg_alpha': 0.3762442154804016, 'reg_lambda': 0.08025926439259225, 'min_child_weight': 9}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:11,026] Trial 83 finished with value: 0.8055782031456072 and parameters: {'n_estimators': 850, 'max_depth': 5, 'learning_rate': 0.058437030279639174, 'subsample': 0.9249107672110262, 'colsample_bytree': 0.6573724879206815, 'gamma': 0.27750405885170626, 'reg_alpha': 0.42130718117446786, 'reg_lambda': 0.11880097698855142, 'min_child_weight': 5}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:11,836] Trial 84 finished with value: 0.8067282478833612 and parameters: {'n_estimators': 813, 'max_depth': 3, 'learning_rate': 0.03775529356833755, 'subsample': 0.9058743327804495, 'colsample_bytree': 0.6393658431497947, 'gamma': 0.3098781343434066, 'reg_alpha': 0.3548588981752214, 'reg_lambda': 0.06701110345962823, 'min_child_weight': 2}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:12,716] Trial 85 finished with value: 0.809892887990111 and parameters: {'n_estimators': 642, 'max_depth': 4, 'learning_rate': 0.025699135515597656, 'subsample': 0.946772844931338, 'colsample_bytree': 0.9019183576814138, 'gamma': 0.24535798052938917, 'reg_alpha': 0.4793080489429828, 'reg_lambda': 0.03476033880345837, 'min_child_weight': 3}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:13,582] Trial 86 finished with value: 0.8060096509420788 and parameters: {'n_estimators': 644, 'max_depth': 4, 'learning_rate': 0.07320017036132234, 'subsample': 0.9416704731828661, 'colsample_bytree': 0.900817267243684, 'gamma': 0.23923551425875317, 'reg_alpha': 0.4697490333707374, 'reg_lambda': 0.49834408325678853, 'min_child_weight': 5}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:14,448] Trial 87 finished with value: 0.8080234187919254 and parameters: {'n_estimators': 579, 'max_depth': 4, 'learning_rate': 0.020246310719246385, 'subsample': 0.8808966199354586, 'colsample_bytree': 0.9219975555061197, 'gamma': 0.13417401776229518, 'reg_alpha': 0.48636883936753944, 'reg_lambda': 0.16850241201739452, 'min_child_weight': 8}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:15,539] Trial 88 finished with value: 0.7973829706903062 and parameters: {'n_estimators': 677, 'max_depth': 10, 'learning_rate': 0.15368087533325564, 'subsample': 0.9505653348145496, 'colsample_bytree': 0.8912027856092494, 'gamma': 0.21196956342892861, 'reg_alpha': 0.0021281718565515917, 'reg_lambda': 0.13797873108238118, 'min_child_weight': 6}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:16,300] Trial 89 finished with value: 0.8055790306647564 and parameters: {'n_estimators': 622, 'max_depth': 3, 'learning_rate': 0.12883429513087025, 'subsample': 0.7530191696877363, 'colsample_bytree': 0.9100312138011977, 'gamma': 0.1602456630102002, 'reg_alpha': 0.33427653051605377, 'reg_lambda': 0.22058412055010101, 'min_child_weight': 10}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:17,009] Trial 90 finished with value: 0.8070174658260452 and parameters: {'n_estimators': 524, 'max_depth': 4, 'learning_rate': 0.04901763296266329, 'subsample': 0.8453411976807069, 'colsample_bytree': 0.7098880293587616, 'gamma': 0.22454272977435674, 'reg_alpha': 0.28026332367034684, 'reg_lambda': 0.10348961166922482, 'min_child_weight': 4}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:18,459] Trial 91 finished with value: 0.8075915572358792 and parameters: {'n_estimators': 784, 'max_depth': 6, 'learning_rate': 0.023784342123133483, 'subsample': 0.9623344080289471, 'colsample_bytree': 0.6202464047380017, 'gamma': 0.2512672944646691, 'reg_alpha': 0.46116664721800066, 'reg_lambda': 0.033881732878982954, 'min_child_weight': 3}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:19,530] Trial 92 finished with value: 0.8090296820774869 and parameters: {'n_estimators': 742, 'max_depth': 4, 'learning_rate': 0.038645452199129425, 'subsample': 0.9796990194287467, 'colsample_bytree': 0.8423447731634439, 'gamma': 0.2697236426461531, 'reg_alpha': 0.43966898246229197, 'reg_lambda': 0.05552056158373686, 'min_child_weight': 2}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:20,483] Trial 93 finished with value: 0.8064419262576997 and parameters: {'n_estimators': 720, 'max_depth': 4, 'learning_rate': 0.06058544958661945, 'subsample': 0.9789049811497298, 'colsample_bytree': 0.8641153689433818, 'gamma': 0.3245022714191797, 'reg_alpha': 0.07585755554239115, 'reg_lambda': 0.05527211442866531, 'min_child_weight': 2}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:21,237] Trial 94 finished with value: 0.8071604197590883 and parameters: {'n_estimators': 742, 'max_depth': 3, 'learning_rate': 0.09574988328464923, 'subsample': 0.9960246586868933, 'colsample_bytree': 0.8367246641031596, 'gamma': 0.28674753352687865, 'reg_alpha': 0.49984511647610086, 'reg_lambda': 0.08381567319796192, 'min_child_weight': 3}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:21,466] Trial 95 finished with value: 0.804283549436511 and parameters: {'n_estimators': 105, 'max_depth': 4, 'learning_rate': 0.08080217080495643, 'subsample': 0.6472496721391798, 'colsample_bytree': 0.8072269906974332, 'gamma': 0.2706595216246501, 'reg_alpha': 0.4817595135065105, 'reg_lambda': 0.03874897554183233, 'min_child_weight': 2}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:22,237] Trial 96 finished with value: 0.8078790167003709 and parameters: {'n_estimators': 695, 'max_depth': 3, 'learning_rate': 0.04072806118462181, 'subsample': 0.9885100942854262, 'colsample_bytree': 0.8250549093357282, 'gamma': 0.234770003406657, 'reg_alpha': 0.3975559078661191, 'reg_lambda': 0.1581186639878588, 'min_child_weight': 1}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:23,160] Trial 97 finished with value: 0.8065848801907431 and parameters: {'n_estimators': 556, 'max_depth': 5, 'learning_rate': 0.0668474832686637, 'subsample': 0.9154832401271011, 'colsample_bytree': 0.8433293821123345, 'gamma': 0.19648430352037669, 'reg_alpha': 0.1056990961506982, 'reg_lambda': 0.07557277049317095, 'min_child_weight': 7}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:23,846] Trial 98 finished with value: 0.7917743562159618 and parameters: {'n_estimators': 659, 'max_depth': 4, 'learning_rate': 0.41856931415707743, 'subsample': 0.9571167454432914, 'colsample_bytree': 0.765979066860649, 'gamma': 0.24417526469882644, 'reg_alpha': 0.4360222085002425, 'reg_lambda': 0.05319600840466965, 'min_child_weight': 4}. Best is trial 74 with value: 0.8101804508944964.
# [I 2025-07-07 23:21:24,661] Trial 99 finished with value: 0.8067286616429359 and parameters: {'n_estimators': 690, 'max_depth': 3, 'learning_rate': 0.14271237426526004, 'subsample': 0.9265074680596556, 'colsample_bytree': 0.8729275355288704, 'gamma': 0.2204461189567522, 'reg_alpha': 0.4516092420723719, 'reg_lambda': 0.1228738382195056, 'min_child_weight': 11}. Best is trial 74 with value: 0.8101804508944964.
# Best trial:
# {'n_estimators': 817, 'max_depth': 3, 'learning_rate': 0.0816525631511912, 'subsample': 0.9618214514489957, 'colsample_bytree': 0.6390303515291257, 'gamma': 0.2256057696902123, 'reg_alpha': 0.40266566984067254, 'reg_lambda': 0.14568814833206822, 'min_child_weight': 3}

# %%
study.best_value
# Out:
# 0.8101804508944964

# %%
train, train_imputers, train_ohe = update_train_df(full_df)
# Out:
# /tmp/ipykernel_131002/3056761461.py:68: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0 1 0 ... 1 0 1]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'Transported'] = df.loc[:, 'Transported'].astype(int)

# %%
test_df = pd.read_csv('dataset/test.csv')
test = update_test_df(test_df, train_imputers, train_ohe)

# %%
X = train.drop('Transported', axis=1)
y = train.loc[:, 'Transported']

# %%
best_params = study.best_trial.params

# %%
best_model = XGBClassifier(**best_params)
best_model.fit(X, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6390303515291257, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, feature_weights=None,
#               gamma=0.2256057696902123, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.0816525631511912,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=3, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=817, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = best_model.predict(test)
y_pre = y_pred.astype(bool)

# %%
test_df = pd.read_csv('dataset/test.csv')


submission = pd.DataFrame({
    'PassengerId': test_df['PassengerId'],
    'Transported' : y_pred.astype(bool)
})
submission
# Out:
#      PassengerId  Transported
# 0        0013_01         True
# 1        0018_01        False
# 2        0019_01         True
# 3        0021_01         True
# 4        0023_01         True
# ...          ...          ...
# 4272     9266_02         True
# 4273     9269_01        False
# 4274     9271_01         True
# 4275     9273_01         True
# 4276     9277_01         True
#
# [4277 rows x 2 columns]

# %%
submission.to_csv('xgboost-81.01.csv', index=False)

# %%
best_params
# Out:
# {'n_estimators': 817,
#  'max_depth': 3,
#  'learning_rate': 0.0816525631511912,
#  'subsample': 0.9618214514489957,
#  'colsample_bytree': 0.6390303515291257,
#  'gamma': 0.2256057696902123,
#  'reg_alpha': 0.40266566984067254,
#  'reg_lambda': 0.14568814833206822,
#  'min_child_weight': 3}
